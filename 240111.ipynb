# %% [markdown]
# <a href="https://colab.research.google.com/github/junu1998/aipython/blob/main/240111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_excel('data1.xlsx')
plt.plot(df['kor'])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_excel('data1.xlsx')
plt.plot(df['kor'], 'k--', marker='o', label='korean')
plt.plot(df['math'], marker='^',label='math')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plot
x = [6,2,1,1,4,4,6,4,7,7]
y = [5,4,2,9,9,0,10,3,1,2]
plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create x and y values
x = np.arange(1, 11)
y = np.random.randint(1, 30, 10)

# Create a scatter plot
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import matplotlib.pyplot as plt
x = ['A','B','C']
y = [100, 150, 120]
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x= [1,1,1,2,3,2,4]
plt.hist(x, bins=4, color='green', align='mid')
plt.show()

# %%
import matplotlib.pyplot as plt
x = ['A','B','C']
y = [100, 150, 120]
plt.bar(x,y)
plt.title('Test Graph')
plt.xlabel('Group')
plt.ylabel('Score')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
fig, axs = plt.subplots(2,2)
axs[0,0].plot(x,y)
axs[0,1].scatter(x,y)
axs[1,0].bar(x,y)
axs[1,1].barh(x,y)
fig.suptitle('Drawing Graph')
plt.show()

# %%
# !sudo apt-get install -y fonts-nanum
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (7,189 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the Excel file
df = pd.read_excel('data1.xlsx')

# Create a line plot
plt.plot(df['name'], df['kor'], label='kor')
plt.plot(df['name'], df['math'], label='math')

# Add a legend
plt.legend()

# Add a title
plt.title('kor, math score')

# Add x and y axes labels
plt.xlabel('name')
plt.ylabel('score')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54616 (\N{HANGUL SYLLABLE HA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")
sns.scatterplot(x='petal_length',y='petal_width'
,hue='species',data=iris)
plt.title('Scatter Plot by seaborn', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-8d7f6472052e> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 iris = sns.load_dataset("iris")
#       4 sns.scatterplot(x='petal_length',y='petal_width'
#       5 ,hue='species',data=iris)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     585         if not os.path.exists(cache_path):
#     586             if name not in get_dataset_names():
# --> 587                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     588             urlretrieve(url, cache_path)
#     589         full_path = cache_path
#
# ValueError: 'iris' is not one of the example datasets.

# %%
import pandas as pd
iris = pd.read_csv('iris.csv', encoding='UTF-8')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

iris = pd.read_csv('iris.csv', encoding='UTF-8')
sns.scatterplot(x='petal_length',y='petal_width'
,hue='species',data=iris)
plt.title('Scatter Plot by seaborn', fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris_data=pd.read_csv('iris.csv', encoding='UTF-8')
sns.countplot(x='species',data=iris_data)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris_data=pd.read_csv('iris.csv', encoding='UTF-8')
sns.barplot(x='species',y='petal_length',data=iris_data, errorbar='sd')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
iris_data=pd.read_csv('iris.csv', encoding='UTF-8')
sns.pairplot(iris_data,hue='species')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris_data=pd.read_csv('iris.csv', encoding='UTF-8')
sns.regplot(x='petal_length',y='petal_width', data=iris_data)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris_data=pd.read_csv('iris.csv', encoding='UTF-8')
df=iris_data.corr()
sns.heatmap(data=df,annot=True,fmt='.2f',cbar=False)
plt.show()
# Out:
# <ipython-input-6-75826492483d>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=iris_data.corr()

# %%
import pandas as pd
penguins = pd.read_csv('penguins.csv', encoding='UTF-8')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

iris = pd.read_csv('penguins.csv', encoding='UTF-8')
sns.barplot(x='species',y='body_mass_g'
,hue='sex',data=penguins)
plt.title('Scatter Plot by seaborn', fontsize=20)
plt.show()

# %%
sns.pairplot(penguins)
plt.show()

# %%
columns = ['body_mass_g', 'bill_length_mm']

sns.scatterplot(x=columns[0], y=columns[1], data=penguins)
sns.lineplot(x=columns[0], y=columns[1], data=penguins)
plt.show()
